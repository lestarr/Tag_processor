# %% [markdown]
# # set up

# %%
import os
from dotenv import load_dotenv

load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
MODEL = "gpt-4o-mini"

# %% [markdown]
# # load data

# %%
texts =  []
input_texts = "../../data/math_books/texts"
for file in os.listdir(input_texts):
    with open(os.path.join(input_texts, file), 'r', encoding='utf-8') as f:
        texts.append(f.read())

# %% [markdown]
# # process single text

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from tag_processor import process_all_products

t_num = 5
text_list = [texts[t_num]]

process_all_products(text_list)
# Out:
# Loaded 24 tags, 5 titles, and 36 synonyms.
# costs prompt: 840, completion: 102
# Synonym for elementary education found: play-based learning
# Synonym for number sense found: mathematics
# Synonym for problem centered learning found: play-based learning
# Synonym for activity sheets found: exercises
# No synonym found for fractions. Adding as a new tag.
# Synonym for decimals found: fractions
# Synonym for algebra found: linear algebra
# Synonym for homeschooling found: self-learning
# No synonym found for grades 5-8. Adding as a new tag.
# No synonym found for research-based. Adding as a new tag.
# Synonym for mathematical fluency found: mathematics
# Processed: Coming To Know Number + Developing Mathematical Fluency Full Text Bundle
# Usage: CompletionUsage(completion_tokens=102, prompt_tokens=840, total_tokens=942)
