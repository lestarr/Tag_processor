# %% [markdown]
# # set cache dir for the tag results

# %%
freq_json = "cache/display_tags/tag_frequency.json"
tag_to_books_json = "cache/display_tags/tag_to_books.json"

# freq_json = 'cache/new_products/tag_frequency.json'
# tag_to_books_json = 'cache/new_products/tag_to_books.json'

# %% [markdown]
# # display tag frequency

# %%
from extraction.tag_processor import visualize_tag_frequency

visualize_tag_frequency(freq_json)
# Out:
# Detailed information for top 100 tags:
#
# Tag: education (Frequency: 31)
# Books:
#
# Tag: mathematics (Frequency: 21)
# Books:
#
# Tag: eBook (Frequency: 17)
# Books:
#
# Tag: beginner (Frequency: 11)
# Books:
#
# Tag: self-paced learning (Frequency: 11)
# Books:
#
# Tag: problem centered learning (Frequency: 11)
# Books:
#
# Tag: hands-on projects (Frequency: 10)
# Books:
#
# Tag: Python (Frequency: 9)
# Books:
#
# Tag: data_science (Frequency: 8)
# Books:
#
# Tag: machine learning (Frequency: 8)
# Books:
#
# Tag: guide (Frequency: 8)
# Books:
#
# Tag: proof writing (Frequency: 6)
# Books:
#
# Tag: programming (Frequency: 5)
# Books:
#
# Tag: book (Frequency: 5)
# Books:
#
# Tag: theory (Frequency: 5)
# Books:
#
# Tag: visualizations (Frequency: 5)
# Books:
#
# Tag: career transition (Frequency: 5)
# Books:
#
# Tag: high school math (Frequency: 5)
# Books:
#
# Tag: number sense (Frequency: 5)
# Books:
#
# Tag: activity sheets (Frequency: 5)
# Books:
#
# ...

# %% [markdown]
# # display tag list with search and filter options

# %%
import sys
import os
import extraction.tag_search_display as tag_search_display

# Call the main function to display the widgets
tag_search_display.main(freq_json, tag_to_books_json)
